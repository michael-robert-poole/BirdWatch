# %%
import tensorflow as tf
from tensorflow import keras
import load_data
from load_data import split_data
import warnings
import numpy as np
import pandas as pd
warnings.filterwarnings('ignore')
# Out:
# 2021-12-07 12:04:35.818633: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-07 12:04:35.818654: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
data = np.load('np_arrays/images_and_labels.npy', allow_pickle=True)
pd_data= pd.DataFrame(data)

# %%
pd_data.head()
# Out:
#                                                    0  1  2
# 0  [[[197, 206, 210], [199, 208, 212], [204, 213,...  0  2
# 1  [[[35, 95, 64], [35, 95, 64], [38, 95, 64], [3...  0  3
# 2  [[[14, 24, 18], [6, 16, 10], [2, 9, 4], [0, 7,...  0  4
# 3  [[[137, 137, 131], [138, 138, 132], [141, 138,...  0  2
# 4  [[[232, 230, 219], [232, 230, 219], [232, 230,...  0  3

# %%
import bird_info
bird_info.visualise_images(images=data[:,0], labels=data[:,1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_14237/3215575428.py in <module>
#       1 import bird_info
# ----> 2 bird_info.visualise_images(images=data[:,0], labels=data[:,1])
#
# ~/uni/birdwatch/BirdWatch/bird_info.py in visualise_images(images, labels, latin)
#      19         ax = plt.subplot(10, 10, j + 1)
#      20         plt.imshow(images[i])
# ---> 21         plt.title(names[labels[i]])
#      22         plt.axis('off')
#      23         j+=1
#
# IndexError: list index out of range
