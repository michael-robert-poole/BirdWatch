# %%
import tensorflow as tf
from tensorflow import keras
import load_data
from load_data import split_data
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2021-12-01 10:52:17.535526: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-01 10:52:17.535570: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
train=load_data.split_data(subset="training", label_mode="categorical", labels="inferred")
# Out:
# Found 3000 files belonging to 10 classes.
# Using 2700 files for training.
# 2021-12-01 10:52:19.691384: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-12-01 10:52:19.691403: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-01 10:52:19.691420: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mike-lenovo-laptop-2): /proc/driver/nvidia/version does not exist
# 2021-12-01 10:52:19.692227: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
val = split_data(subset="validation", label_mode="categorical", labels="inferred")
# Out:
# Found 3000 files belonging to 10 classes.
# Using 300 files for validation.

# %%
test=tf.keras.preprocessing.image_dataset_from_directory("val_ten_uk_birds/", labels="inferred", label_mode="categorical")
# Out:
# Found 100 files belonging to 10 classes.

# %%
import bird_info
from bird_info import Bird_info
all_birds = Bird_info()
all_birds.visualise_images(data=train)
# Out:
# 2021-12-01 10:52:26.486254: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
