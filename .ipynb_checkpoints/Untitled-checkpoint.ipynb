# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
train=tf.keras.preprocessing.image_dataset_from_directory("all_birds", labels="inferred", label_mode="categorical", subset="training", seed=133, validation_split=0.2, image_size=(256,256))
# Out:
# Found 500 files belonging to 10 classes.
# Using 400 files for training.

# %%
test=tf.keras.preprocessing.image_dataset_from_directory("val_ten_uk_birds/", labels="inferred", label_mode="int")
# Out:
# Found 100 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, _ in train.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        #plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9017/2269875772.py in <module>
#       6         ax = plt.subplot(3, 3, i + 1)
#       7         plt.imshow(images[i].numpy().astype("uint8"))
# ----> 8         plt.title(labels)
#       9         plt.axis("off")
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3285 @_copy_docstring_and_deprecators(Axes.set_title)
#    3286 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
# -> 3287     return gca().set_title(
#    3288         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    3289
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     162             pad = rcParams['axes.titlepad']
# ...

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(256,256,3))
x = data_augmentation(inputs)
x = keras.layers.Rescaling(1./255)(x)

# %%
image_size=(256,256)

# %%
def leNet_5_max_pool_v2():
    model = keras.Sequential()

    model.add(layers.Conv2D(filters=6, kernel_size=(5, 5), strides=1, padding="valid", activation='relu', input_shape=(256,256,3), kernel_regularizer=keras.regularizers.l2(l=0.01)))
    model.add(layers.MaxPooling2D(pool_size=(2,2), strides=2, padding="valid"))

    model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), strides=1, padding="valid", activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))
    model.add(layers.MaxPooling2D(pool_size=(2,2), strides=2, padding="valid"))

    model.add(layers.Flatten())

    model.add(layers.Dense(units=120, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))

    model.add(layers.Dense(units=84, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))

    model.add(layers.Dense(units=10, activation = 'softmax'))
    return model

# %%
m=leNet_5_max_pool_v2()
m.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_24 (Conv2D)           (None, 252, 252, 6)       456
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 126, 126, 6)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 122, 122, 16)      2416
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 61, 61, 16)        0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 59536)             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 120)               7144440
# _________________________________________________________________
# dense_37 (Dense)             (None, 84)                10164
# ...

# %%
m=leNet_5_max_pool_v2()
m.summary()
m.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy', tf.keras.metrics.Recall()])
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_26 (Conv2D)           (None, 252, 252, 6)       456
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 126, 126, 6)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 122, 122, 16)      2416
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 61, 61, 16)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 59536)             0
# _________________________________________________________________
# dense_39 (Dense)             (None, 120)               7144440
# _________________________________________________________________
# dense_40 (Dense)             (None, 84)                10164
# ...

# %%
m.fit(train,epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 13/13 [==============================] - 10s 668ms/step - loss: 102.4231 - accuracy: 0.0950 - recall_6: 0.0900
# Epoch 2/10
# 13/13 [==============================] - 10s 761ms/step - loss: 6.9423 - accuracy: 0.1775 - recall_6: 0.0575
# Epoch 3/10
# 13/13 [==============================] - 12s 887ms/step - loss: 5.4372 - accuracy: 0.4775 - recall_6: 0.1350
# Epoch 4/10
# 13/13 [==============================] - 12s 882ms/step - loss: 4.7076 - accuracy: 0.7200 - recall_6: 0.4400
# Epoch 5/10
# 13/13 [==============================] - 12s 894ms/step - loss: 4.0262 - accuracy: 0.9225 - recall_6: 0.7700
# Epoch 6/10
# 13/13 [==============================] - 11s 819ms/step - loss: 3.7099 - accuracy: 0.9800 - recall_6: 0.9375
# Epoch 7/10
# 13/13 [==============================] - 10s 788ms/step - loss: 3.5549 - accuracy: 0.9925 - recall_6: 0.9750
# Epoch 8/10
# 13/13 [==============================] - 12s 881ms/step - loss: 3.4420 - accuracy: 0.9925 - recall_6: 0.9900
# ...
